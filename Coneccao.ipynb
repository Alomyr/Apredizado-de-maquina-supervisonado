# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Failed to start the Kernel.
#
# Failed to connect to the remote Jupyter Server 'Colab CPU'. Verify the server is running and reachable. (request to https://colab.pa.googleapis.com/v1/assignments failed, reason: getaddrinfo EAI_AGAIN colab.pa.googleapis.com).
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
