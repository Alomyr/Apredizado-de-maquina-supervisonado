# %% [markdown]
# # **Impotando o modelo pré-treinado**

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import numpy as np

import sys
sys.path.insert(0, '/content/drive/MyDrive/IMD3002 - Aprendizado de Máquina Supervisionado/3-unidade/')

from toolbox import MyModel

# %% [markdown]
# ### **1. Importando os dados de teste:**

# %%
X_test = np.load("/content/drive/MyDrive/IMD3002 - Aprendizado de Máquina Supervisionado/3-unidade/dataset/x_test.npy")
y_test = np.load("/content/drive/MyDrive/IMD3002 - Aprendizado de Máquina Supervisionado/3-unidade/dataset/y_test.npy")

X_test.shape, y_test.shape
# Out:
# ((3504, 6), (3504,))

# %% [markdown]
# ### **2. Impotando o modelo:**

# %%
model = MyModel()

model.load_weights("/content/drive/MyDrive/IMD3002 - Aprendizado de Máquina Supervisionado/3-unidade/weights/model.weights.h5")

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 6)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │           224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │           264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 497 (1.94 KB)
#  Trainable params: 497 (1.94 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### **3. Avaliando o modelo:**

# %%
model.compile(loss='mse', metrics=['mae'])

mse, mae = model.evaluate(x=X_test, y=y_test, batch_size=16)

print(f"\nMSE = {mse:.4f}, MAE = {mae:.4f}\n")
# Out:
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0014 - mae: 0.0226
#
# MSE = 0.0014, MAE = 0.0226

# %%
y_pred = model.predict(X_test)

print("\ny-pred | y-test")
print("---------------")

for p, y in zip(y_pred[:10], y_test[:10]):

    print(f" {p[0]:.2f}  |  {y:.2f}")
# Out:
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# y-pred | y-test
# ---------------
#  0.01  |  0.00
#  0.01  |  0.00
#  0.01  |  0.00
#  0.01  |  0.00
#  0.32  |  0.29
#  0.01  |  0.00
#  0.69  |  0.71
#  0.01  |  0.00
#  0.12  |  0.14
#  0.01  |  0.00

# %% [markdown]
# ## **Referências:**
# <font size=3>
#
#  - **(3.4):** F. Chollet, *Deep Learning with Python*. Manning, 2018.
